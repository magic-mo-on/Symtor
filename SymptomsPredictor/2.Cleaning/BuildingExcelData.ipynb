# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import time
from itertools import combinations

# %%
with open('../finalData/pickle/diseases_symptoms_cleaned.pickle', 'rb') as handle:
    diseases_symptoms_cleaned = pickle.load(handle)
with open('../finalData/pickle/new_symptoms.pickle', 'rb') as handle:
    new_symptoms = pickle.load(handle)
with open('../finalData/pickle/symptom_match.pickle', 'rb') as handle:
    symptom_match = pickle.load(handle)

# %%
total_symptoms = new_symptoms.copy()
total_symptoms = list(total_symptoms)
total_symptoms.sort()
total_symptoms=['label_dis']+total_symptoms

# %%
f = open("../Analyze/4.disease symptoms length.txt", "w")
for dis in sorted(diseases_symptoms_cleaned.keys()):
    f.write(dis+" --> "+str(len(diseases_symptoms_cleaned[dis]))+"\n")
f.close()

# %% [markdown]
# # initializing data frame

# %%
# df_comb = pd.DataFrame(columns=total_symptoms)
# df_norm = pd.DataFrame(columns=total_symptoms)
# combination_dict=dict()
# normal_dict=dict()

# %%
picklefile = open('../finalData/pickle/df_norm.pkl', 'rb')
df_norm = pickle.load(picklefile)
picklefile = open('../finalData/pickle/df_comb.pkl', 'rb')
df_comb = pickle.load(picklefile)

# %%
def write(df_norm,df_comb):
    df_norm.to_pickle("../finalData/pickle/df_norm.pkl")
    df_comb.to_pickle("../finalData/pickle/df_comb.pkl")
write(df_norm,df_comb)

# %%
diseases_symptoms_cleaned_temp=diseases_symptoms_cleaned.copy()
count=0
for disease in diseases_symptoms_cleaned:
    if disease=="Shin splints":
        break
    del diseases_symptoms_cleaned_temp[disease]
    count+=1
diseases_symptoms_cleaned=diseases_symptoms_cleaned_temp.copy()
print(count,"diseases deleted")
# Out:
# 410 diseases deleted

# %%
start_time = time.time()
count=0
for key, values in diseases_symptoms_cleaned.items():
    print(key)
    count+=1
    key = str.encode(key).decode('utf-8')
    tmp = []
    
    # For similar symptoms, replace with the value in dictionary
    for symptom in values:
        if symptom in symptom_match.keys():
            tmp.append(symptom_match[symptom])
            # print(symptom)
        else:
            tmp.append(symptom)
            
    values = list(set(tmp))
    diseases_symptoms_cleaned[key] = values
    
    # Populate row for normal
    row_norm = dict({x:0 for x in total_symptoms})
    for sym in values:
        row_norm[sym] = 1
    row_norm['label_dis']=key
    df_norm = df_norm.append(pd.Series(row_norm), ignore_index=True)
    # Populate rows for combination dataset
    for comb in range(1, len(values) + 1):
        for subset in combinations(values, comb):
            row_comb = dict({x:0 for x in total_symptoms})
            for sym in list(subset):
                row_comb[sym]=1
            row_comb['label_dis']=key
            df_comb = df_comb.append(pd.Series(row_comb), ignore_index=True)
    if count==10:
        write(df_norm,df_comb)
        print("--------------------------data written----------------------------")
        count=0
write(df_norm,df_comb)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Shin splints
# Shingles
# Shoulder impingement
# Sickle cell anemia
# Sinusitis (sinus infection)
# Sjögren's syndrome
# Skin cancer (melanoma)
# Skin tags
# Slapped cheek syndrome
# Sleep apnoea
# --------------------------data written----------------------------
# Sleep paralysis
# Sleepwalking
# Slipped disc
# Soil-transmitted helminthiasis
# Spider bite
# Spina bifida
# Spinal cord injury
# Spondylitis
# Spondylolisthesis
# Spondylosis
# --------------------------data written----------------------------
# Sprained ankle
# Staph infection
# Stasis dermatitis
# Stomach cancer
# Stomach flu
# Stomach ulcer
# Strep throat
# Stroke
# Stye
# Subconjunctival hemorrhage
# --------------------------data written----------------------------
# Sunburn
# Supraventricular tachycardia (SVT)
# Swimmer's ear
# Swine flu
# Syndrome of inappropriate antidiuretic hormone secretion
# Syphilis
# Taeniasis
# Tardive dyskinesia
# Temporal arteritis
# Temporomandibular disorder (TMD)
# --------------------------data written----------------------------
# Tennis elbow
# Tension-type headaches
# Testicular torsion
# Thalassemia
# Thoracic outlet syndrome
# Thyroid cancer
# Thyroid nodules
# Thyroiditis
# Tonsil stones
# Tonsillitis
# --------------------------data written----------------------------
# Torn meniscus
# Torticollis
# Tourette syndrome
# Toxoplasmosis
# Transient ischaemic attack (TIA)
# Traumatic brain injury
# Trichomoniasis
# Trigeminal neuralgia
# Trigger finger
# Trochanteric bursitis
# --------------------------data written----------------------------
# Tuberculosis
# Turner syndrome
# Type 1 diabetes
# Type 2 diabetes
# Ulcerative colitis
# Umbilical hernia
# Underactive thyroid (hypothyroidism)
# Upper respiratory infection
# Uterine cancer
# Uveitis
# --------------------------data written----------------------------
# Vaginal yeast infection
# Vaginitis
# Varicose veins
# Vasculitis
# Ventricular septal defect
# Vitamin B12 deficiency
# Vitiligo
# Von Willebrand disease
# Warts and verrucas
# Whiplash
# --------------------------data written----------------------------
# Whooping cough
# --- 46831.734414339066 seconds ---

# %%
print(df_comb.shape)
print(df_norm.shape)
# Out:
# (131005, 824)
# (491, 824)

# %%
df_comb.to_csv("../finalData/dis_sym_dataset_comb.csv",index=None)
df_norm.to_csv("../finalData/dis_sym_dataset_norm.csv",index=None)
